# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ##**Data Exploration, Processing & Cleaning**
#
# **Load the dataset into a pandas DataFrame.**

# %%
data=pd.read_csv("/content/drive/MyDrive/Dataset_creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# **Check for any missing values and handle them accordingly.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.dtypes.value_counts()
# Out:
# float64    30
# int64       1
# Name: count, dtype: int64

# %%
data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# **Check for the duplicate values**

# %%
data.duplicated().sum()
# Out:
# 1081

# %%
data[data.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
data[113:115]
# Out:
#      Time       V1        V2        V3       V4        V5        V6        V7  \
# 113  74.0  1.03837  0.127486  0.184456  1.10995  0.441699  0.945283 -0.036715
# 114  74.0  1.03837  0.127486  0.184456  1.10995  0.441699  0.945283 -0.036715
#
#            V8       V9  ...      V21       V22       V23       V24      V25  \
# 113  0.350995  0.11895  ...  0.10252  0.605089  0.023092 -0.626463  0.47912
# 114  0.350995  0.11895  ...  0.10252  0.605089  0.023092 -0.626463  0.47912
#
#           V26       V27       V28  Amount  Class
# 113 -0.166937  0.081247  0.001192    1.18      0
# 114 -0.166937  0.081247  0.001192    1.18      0
#
# [2 rows x 31 columns]

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %% [markdown]
# **Explore and visualize the dataset to identify any outliers or anomalies.**

# %%
import seaborn as sns
fig = plt.figure(figsize = (30, 10))
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
normal = data[data.Class == 0]
fraud = data[data.Class == 1]

plt.figure(figsize=(8, 6))
plt.scatter(normal.Time, normal.Amount, alpha=0.6, label='Normal')
plt.scatter(fraud.Time, fraud.Amount, alpha=0.9, label='Fraud')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.title('Amount vs Time (Normal vs Fraud)')
plt.legend()
plt.show()

# %% [markdown]
# **Balance the dataset if necessary by undersampling the majority class or oversampling the minority class.**

# %%
len(data[data['Class']==1])
# Out:
# 473

# %%
len(data[data['Class']==0])
# Out:
# 283253

# %%
classes=data['Class'].value_counts()
normal=classes[0]/data['Class'].count()*100
fraud=classes[1]/data['Class'].count()*100
print(normal,fraud)
# Out:
# 99.83328986416473 0.1667101358352777

# %%
plt.figure(figsize=(8,6))
plt.pie(classes,labels=['Normal','Fraud'],autopct='%1.1f%%')
plt.title("Distribution of Transactions")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Class', data=data);

# %%
x=data.drop(['Class'],axis=1)
y=data['Class']
x.shape,y.shape
# Out:
# ((283726, 30), (283726,))

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
x_1, y_1 = smote.fit_resample(x, y)

print(x_1.shape, y_1.shape)
# Out:
# (566506, 30) (566506,)

# %%
plt.figure(figsize=(10,6))

sns.countplot(x=y_1,palette=['blue','red']);
# Out:
# <ipython-input-25-3a426c75e0ce>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y_1,palette=['blue','red']);

# %% [markdown]
# ##Feature Selection & Engineering
# Identify relevant features for the model and drop irrelevant features.
# **Normalize the numerical features.**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_1['Amount'] = scaler.fit_transform(x_1['Amount'].values.reshape(-1, 1))

# %%
corr=x_1.corr()
plt.figure(figsize=(24,20))
sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# **Engineer new features that may be useful for the model, such as time-based features.**

# %%
delta_time = pd.to_timedelta(x_1['Time'], unit='s')
x_1['Time_Day'] = (delta_time.dt.components.days).astype(float)
x_1['Time_Hour'] = (delta_time.dt.components.hours).astype(float)
x_1['Time_Minute'] = (delta_time.dt.components.minutes).astype(float)
x_1.tail(100)
# Out:
#                  Time         V1        V2         V3        V4         V5  \
# 566406   77158.350872  -0.823477  0.866485   0.618937  0.064794  -0.437463
# 566407   96138.565549  -6.763352  7.069363  -7.251075  7.716405  -4.801042
# 566408   55951.156905  -3.125858  2.259609  -3.245766  3.527628  -2.784975
# 566409   41349.428576 -14.869192  7.974441 -16.086599  5.890548 -11.885519
# 566410  133324.310495  -1.191001 -2.079132  -6.293236  3.922326  -1.157655
# ...               ...        ...       ...        ...       ...        ...
# 566501   41183.445750  -7.151786  5.337862 -10.524210  6.638176  -7.107253
# 566502   14264.057012  -4.705909  8.250299 -14.559164  9.787990  -4.117161
# 566503  135064.971368   0.407366  1.352354  -4.892782  3.554728  -1.282114
# 566504  109361.849259   0.580032  2.773047  -5.790024  5.606953   0.398480
# 566505   84438.552579  -2.819178  2.410529  -5.833727  4.099991  -2.622497
#
# ...

# %% [markdown]
# **By Experimenting with different Time features and their impact on model's performance below features are dropped**

# %%
x_1.drop(['Time'],axis=1,inplace=True)
x_1.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V23       V24       V25       V26  \
# 0  0.098698  0.363787  0.090794  ... -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425 -0.166974  ...  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  0.207643  ...  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024 -0.054952  ... -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  0.753074  ... -0.137458  0.141267 -0.206010  0.502292
#
#         V27       V28    Amount  Time_Day  Time_Hour  Time_Minute
# ...

# %% [markdown]
# ##Model Selection

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_1,y_1,test_size=0.3,random_state=40)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression()
model1.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# accuracy score on train data

# %%
from sklearn.metrics import accuracy_score
x_train_pred = model1.predict(x_train)
accuracy_score(y_train, x_train_pred)
# Out:
# 0.9784745583199261

# %% [markdown]
# accuracy score on test data

# %%
x_test_pred = model1.predict(x_test)
accuracy_score(y_test, x_test_pred)
# Out:
# 0.9783115232536246

# %%
model1.score(x_test,y_test)
# Out:
# 0.9783115232536246

# %%
y_pred=model1.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm=confusion_matrix(y_test,y_pred)
print(cm)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[84245   755]
#  [ 2931 82021]]
# 0.9783115232536246
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     85000
#            1       0.99      0.97      0.98     84952
#
#     accuracy                           0.98    169952
#    macro avg       0.98      0.98      0.98    169952
# weighted avg       0.98      0.98      0.98    169952

# %% [markdown]
# ##**Model Tuning**
# Tune hyperparameters using techniques like GridSearchCV or RandomizedSearchCV.
#
# Import Necessary Libraries:
# Import GridSearchCV or RandomizedSearchCV from sklearn.model_selection.
#
# Define Hyperparameter Grid:
# Create a dictionary defining the hyperparameters and their respective ranges to be tested.
#
# Initialize the Search Method:
# Create an instance of GridSearchCV or RandomizedSearchCV with the model, hyperparameter grid, and desired evaluation metrics.
#
# Fit the Search Method:
# Use the fit method to run the hyperparameter search on the training data.
#
# Extract Best Model:
# Retrieve the best model and hyperparameters from the search results.

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
param_grid_l1 = {
    'penalty': ['l2'],
    'C': [0.1,10,0.05,1],
    'max_iter': [500,1000,2000]
}

# %%
param_grid_l2 = {
    'penalty': ['l1'],
    'C': [0.1,10,0.05,1],
    'max_iter': [500,1000,2000],
    'solver': ['liblinear']
    }

# %% [markdown]
# **GridSearchCV**

# %%
#model3=LogisticRegression()
#grid_search = GridSearchCV(model3, param_grid_l1, cv=5, scoring='accuracy', n_jobs=-1)
#grid_search.fit(x_train, y_train)
#print("Best Parameters:", grid_search.best_params_)
#print("Best Score:", grid_search.best_score_)
#best_model = grid_search.best_estimator_

# %%
#model4=LogisticRegression()
#grid_search = GridSearchCV(model4, param_grid_l2, cv=5, scoring='accuracy', n_jobs=-1)
#grid_search.fit(x_train, y_train)
#print("Best Parameters:", grid_search.best_params_)
#print("Best Score:", grid_search.best_score_)
#best_model = grid_search.best_estimator_

# %% [markdown]
# **RandomizedSearchCV**

# %%
model5=LogisticRegression()
random_search = RandomizedSearchCV(model5, param_grid_l1, cv=5, scoring='f1', n_iter=10, n_jobs=-1)
random_search.fit(x_train, y_train)
print("Best Parameters:", random_search.best_params_)
print("Best Score:", random_search.best_score_)
best_model = random_search.best_estimator_
# Out:
# Best Parameters: {'penalty': 'l2', 'max_iter': 2000, 'C': 10}
# Best Score: 0.9784902669409199

# %%
model6=LogisticRegression()
random_search1 = RandomizedSearchCV(model6, param_grid_l2, cv=5, scoring='f1', n_iter=10, n_jobs=-1)
random_search1.fit(x_train, y_train)
print("Best Parameters:", random_search1.best_params_)
print("Best Score:", random_search1.best_score_)
best_model = random_search1.best_estimator_

# %% [markdown]
# ##**Model Testing**

# %%
from sklearn.linear_model import LogisticRegression
model7=LogisticRegression(penalty='l1',C=1,max_iter=2000)
model7.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=10, max_iter=500)

# %%
y_pred=model7.predict(x_test)
y_pred

# %%
model7.score(x_test,y_test)
# Out:
# 0.9785233477687818

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm=confusion_matrix(y_test,y_pred)
print(cm)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[84248   752]
#  [ 2898 82054]]
# 0.9785233477687818
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     85000
#            1       0.99      0.97      0.98     84952
#
#     accuracy                           0.98    169952
#    macro avg       0.98      0.98      0.98    169952
# weighted avg       0.98      0.98      0.98    169952

# %% [markdown]
# ##**Evaluation Metrics**

# %% [markdown]
# **Calculate performance metrics such as accuracy, precision, recall, F1-score, and AUC-ROC.**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.9785233477687818
# Precision: 0.9909185324734923
# Recall: 0.9658866183256427
# F1-score: 0.9782424683174572
# AUC-ROC: 0.9785197797510566

# %% [markdown]
# ##**Confusion Matrix**
# **Plot and analyze the confusion matrix to understand the model's performance on different classes.**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Compute Confusion Matrix
conf_mat = confusion_matrix(y_test, y_pred)

# Visualize Confusion Matrix
disp = ConfusionMatrixDisplay(conf_mat)
disp.plot()

# %%
from sklearn.metrics import roc_curve, auc

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Predict probabilities instead of class labels
y_pred_proba = model7.predict_proba(x_test)[:, 1]

# Set a lower threshold for classifying as positive (e.g., 0.3)
threshold = 0.4
y_pred_adjusted = (y_pred_proba >= threshold).astype(int)

# Evaluate performance with adjusted threshold
cm_adjusted = confusion_matrix(y_test, y_pred_adjusted)
print(cm_adjusted)
print(accuracy_score(y_test, y_pred_adjusted))
print(classification_report(y_test, y_pred_adjusted))
# Out:
# [[83940  1060]
#  [ 2544 82408]]
# 0.9787940124270382
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     85000
#            1       0.99      0.97      0.98     84952
#
#     accuracy                           0.98    169952
#    macro avg       0.98      0.98      0.98    169952
# weighted avg       0.98      0.98      0.98    169952

# %% [markdown]
# XGBoost

# %%
import xgboost as xgb
model2 = xgb.XGBClassifier()
model2.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=model2.predict(x_test)
y_pred

# %% [markdown]
# accuracy score on training data

# %%
from sklearn.metrics import accuracy_score
x_train_pred = model2.predict(x_train)
accuracy_score(y_train, x_train_pred)
# Out:
# 1.0

# %% [markdown]
# accuracy on test data

# %%
x_test_pred = model2.predict(x_test)
accuracy_score(y_test, x_test_pred)
# Out:
# 0.9998764356994916

# %%
model2.score(x_test,y_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm=confusion_matrix(y_test,y_pred)
print(cm)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[84979    21]
#  [    0 84952]]
# 0.9998764356994916
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85000
#            1       1.00      1.00      1.00     84952
#
#     accuracy                           1.00    169952
#    macro avg       1.00      1.00      1.00    169952
# weighted avg       1.00      1.00      1.00    169952

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.9998764356994916
# Precision: 0.9997528626740259
# Recall: 1.0
# F1-score: 0.9998764160659114
# AUC-ROC: 0.9998764705882354

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Compute Confusion Matrix
conf_mat = confusion_matrix(y_test, y_pred)

# Visualize Confusion Matrix
disp = ConfusionMatrixDisplay(conf_mat)
disp.plot()

# %%
from sklearn.metrics import roc_curve, auc

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ***Conclusion*** : From the above used model it was observed that
#
# **1**.While using Smote Oversampling Technique with Logistic Regression model is giving recall 0.97 for fraud class and 0.99 for normal class with accuracy
# 0.9791.
#
# **2**.After hyperparameter tuning  model is giving recall 0.97 for fraud class and 0.99 for normal class with accuracy 0.9793, which is slightly better.
#
# **3**.On the other side after using xgboost model is giving recall and f1 score for both normal and fraud class was 1 with accuracy 0.9998.
# Hence it is concluded that xgboost model is the best in Credit Card Fraud Detection.
